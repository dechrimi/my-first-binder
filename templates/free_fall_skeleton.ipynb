# %%
using OrdinaryDiffEq,Plots

# %%
const g = 9.81
# Out:
# 9.81

# %%
function free_fall!(du,u,p,t)
    du[1] = ... # fill in the appropriate stuff
    du[2] = ... # fill in the appropriate stuff
end
# Out:
# free_fall! (generic function with 1 method)

# %%
tspan = (0.0,3.0)
u0=[50;0]  # initial conditions
proba = ODEProblem(free_fall!,u0,tspan)
sola = solve(proba,Tsit5(),reltol=1e-6)
plot(sola,idxs=(1))
